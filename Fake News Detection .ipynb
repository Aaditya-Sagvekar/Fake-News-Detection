# %%
import pandas as pd
import numpy as np
import re
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
nltk.download("stopwords")
from nltk.stem import PorterStemmer,WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df=pd.read_csv("C:/Users/Admin/Downloads/WELFake_Dataset.csv/WELFake_Dataset.csv")

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1               1                                                NaN
# 2               2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3               3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4               4  SATAN 2: Russia unvelis an image of its terrif...
# ...           ...                                                ...
# 72129       72129  Russians steal research on Trump in hack of U....
# 72130       72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131       72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132       72132  Trump tussle gives unpopular Mexican leader mu...
# 72133       72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# ...

# %%
df.shape
# Out:
# (72134, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72134 entries, 0 to 72133
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  72134 non-null  int64
#  1   title       71576 non-null  object
#  2   text        72095 non-null  object
#  3   label       72134 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 2.2+ MB

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# title         558
# text           39
# label           0
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 2               2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3               3  Bobby Jindal, raised Hindu, uses story of Chri...
# 4               4  SATAN 2: Russia unvelis an image of its terrif...
# 5               5  About Time! Christian Group Sues Amazon and SP...
# ...           ...                                                ...
# 72129       72129  Russians steal research on Trump in hack of U....
# 72130       72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131       72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132       72132  Trump tussle gives unpopular Mexican leader mu...
# 72133       72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# ...

# %%
df.shape
# Out:
# (71537, 4)

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    index  Unnamed: 0                                              title  \
# 0      0           0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      2           2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      3           3  Bobby Jindal, raised Hindu, uses story of Chri...
# 3      4           4  SATAN 2: Russia unvelis an image of its terrif...
# 4      5           5  About Time! Christian Group Sues Amazon and SP...
#
#                                                 text  label
# 0  No comment is expected from Barack Obama Membe...      1
# 1   Now, most of the demonstrators gathered last ...      1
# 2  A dozen politically active pastors came here f...      0
# 3  The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 4  All we can say on this one is it s about time ...      1

# %%
df['title'][0]
# Out:
# 'LAW ENFORCEMENT ON HIGH ALERT Following Threats Against Cops And Whites On 9-11By #BlackLivesMatter And #FYF911 Terrorists [VIDEO]'

# %%
df=df.drop(['index','text'],axis=1)
df.head()
# Out:
#    Unnamed: 0                                              title  label
# 0           0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...      1
# 1           2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...      1
# 2           3  Bobby Jindal, raised Hindu, uses story of Chri...      0
# 3           4  SATAN 2: Russia unvelis an image of its terrif...      1
# 4           5  About Time! Christian Group Sues Amazon and SP...      1

# %% [markdown]
# # Data Processing

# %% [markdown]
# #  1.Tokenization

# %%
sample_data='studies aborad'
sample_data.split()
# Out:
# ['studies', 'aborad']

# %% [markdown]
# # 2.Make Lowercase

# %%
sampledata="AADITYA"
sampledata.lower()
# Out:
# 'aaditya'

# %%
stopwords=stopwords.words("english")
print(stopwords[0:10])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %% [markdown]
# # 3.Stemming- Stemming is the process of reducing a word to its root form by cutting off prefixes or suffixes.
# It does not always produce a real English word.

# %%
ps=PorterStemmer()
sampledatastemming=[ps.stem(data) for data in sample_data]
print(sampledatastemming)
# Out:
# ['s', 't', 'u', 'd', 'i', 'e', 's', ' ', 'a', 'b', 'o', 'r', 'a', 'd']

# %% [markdown]
# # 4.Lemmatization-Lemmatization reduces a word to its base form (lemma) using vocabulary + grammar rules.
# It always returns a real English word.

# %%
from nltk.stem import WordNetLemmatizer
lm = WordNetLemmatizer()
sample_data = "studies"
words = sample_data.split() 
sampledatalemma = [lm.lemmatize(word) for word in words]
print(sampledatalemma)
# Out:
# ['study']

# %%
lm=WordNetLemmatizer()
corpus=[]
for i in range(len(df)):
    review=re.sub('^a-zA-Z0-9',' ',df['title'][i])
    review=review.lower()
        review=review.split()
    review=[lm.lemmatize(x) for x in review if x not in stopwords]
    review=" ".join(review)
    corpus.append(review)

# %%
len(corpus)
# Out:
# 71537

# %%
df['title'][0]
# Out:
# 'LAW ENFORCEMENT ON HIGH ALERT Following Threats Against Cops And Whites On 9-11By #BlackLivesMatter And #FYF911 Terrorists [VIDEO]'

# %%
corpus[0]
# Out:
# 'law enforcement high alert following threat cop white 9-11by #blacklivesmatter #fyf911 terrorist [video]'

# %% [markdown]
# # Tfidfctorizer-Used for converting text into numbers bcz ML  understands only numbers.

# %%
tf=Tfidfvectorizer()Ve
x=tf.fit_transform(corpus)
x
# Out:
# <71537x29223 sparse matrix of type '<class 'numpy.float64'>'
# 	with 652186 stored elements in Compressed Sparse Row format>

# %%
y=df['label']
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: label, dtype: int64

# %% [markdown]
# # Data splitting into train and test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10,stratify=y)

# %%
x_train.shape[0], y_train.shape[0]
# Out:
# (50075, 50075)

# %%
x_test.shape[0], y_test.shape[0]
# Out:
# (21462, 21462)

# %% [markdown]
# # Model building

# %% [markdown]
# # RandomForestClassifier- is a machine learning algorithm used for classification tasks.
# # Imagine a group of 100 doctors giving a diagnosis. Each doctor gives their opinion (decision tree), and the majority vote is taken as the final decision. This is exactly how Random Forest works.

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Model evaluation

# %%
y_pred=rf.predict(x_test)
accuracy_score=accuracy_score(y_test,y_pred)
accuracy_score
# Out:
# 0.9033640853601714

# %%
class evaluation:
    def __init__(self,model,x_train,x_test,y_train,y_test):
        self.model=model
        self.x_train=x_train
        self.x_test=x_test
        self.y_train=y_train
        self.y_test=y_test
    def train_evaluation(self):
        y_pred_train=self.model.predict(self.x_train)
        acc_scr_train=accuracy_score(self.y_train,y_pred_train)
        print("accuracy score on training data set:",acc_scr_train)
        print()
        con_matrix_train=confusion_matrix(self.y_train,y_pred_train)
        print("confusion matrix on training data set:\n",con_matrix_train)
        print()
        classification_report_train=classification_report(self.y_train,y_pred_train)
        print("classification report on training data set:\n",classification_report_train)

    def test_evaluation(self):
        y_pred_test=self.model.predict(self.x_test)
        acc_scr_test=accuracy_score(self.y_test,y_pred_test)
        print("accuracy score on testing data set:",acc_scr_test)
        print()
        con_matrix_test=confusion_matrix(self.y_test,y_pred_test)
        print("confusion matrix on testing data set:\n",con_matrix_test)
        print()
        classification_report_test=classification_report(self.y_test,y_pred_test)
        print("classification report on testing data set:\n",classification_report_test)

# %% [markdown]
# # checking the accuracy of training data set

# %%
evaluation(rf,x_train,x_test,y_train,y_test).train_evaluation()
# Out:
# accuracy score on training data set: 0.999900149775337
#
# confusion matrix on training data set:
#  [[24517     2]
#  [    3 25553]]
#
# classification report on training data set:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     24519
#            1       1.00      1.00      1.00     25556
#
#     accuracy                           1.00     50075
#    macro avg       1.00      1.00      1.00     50075
# weighted avg       1.00      1.00      1.00     50075

# %% [markdown]
# # checking the accuracy of testing data set

# %%
evaluation(rf,x_train,x_test,y_train,y_test).test_evaluation()
# Out:
# accuracy score on testing data set: 0.9033640853601714
#
# confusion matrix on testing data set:
#  [[ 9298  1211]
#  [  863 10090]]
#
# classification report on testing data set:
#                precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90     10509
#            1       0.89      0.92      0.91     10953
#
#     accuracy                           0.90     21462
#    macro avg       0.90      0.90      0.90     21462
# weighted avg       0.90      0.90      0.90     21462

# %% [markdown]
# # Prediction Pipeline

# %%
class Preprocessing:
    def __init__(self,data):
        self.data=data
    def text_preprocessing_user(self):
        lm=WordNetLemmatizer()
        stop_words = set(stopwords.words("english"))
        pred_data=[self.data]
        preprocess_data=[]
        for data in pred_data:
            review=re.sub('^a-zA-Z0-9',' ',data)
            review=review.lower()
            review=review.split()
            review=[lm.lemmatize(x) for x in review if x not in stop_words]
            review=" ".join(review)
            preprocess_data.append(review)
        return preprocess_data

# %%
df['title'][1]
# Out:
# 'UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MOST CHARLOTTE RIOTERS WERE “PEACEFUL” PROTESTERS…In Her Home State Of North Carolina [VIDEO]'

# %%
data ='UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MOST CHARLOTTE RIOTERS WERE “PEACEFUL” PROTESTERS…In Her Home State Of North Carolina [VIDEO]'
Preprocessing(data).text_preprocessing_user()
# Out:
# ['unbelievable! obama’s attorney general say charlotte rioter “peaceful” protesters…in home state north carolina [video]']

# %%
class Prediction:
    def __init__(self,pred_data,model):
        self.pred_data=pred_data
        self.model=model
    def prediction_model(self):
        preprocess_data=Preprocessing(self.pred_data).text_preprocessing_user()
        data=tf.transform(preprocess_data)
        prediction=self.model.predict(data)
        if prediction[0]==0:
            return "The News is Real"
        else:
            return "The News is Fake"

# %%
data ='UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MOST CHARLOTTE RIOTERS WERE “PEACEFUL” PROTESTERS…In Her Home State Of North Carolina [VIDEO]'
Prediction(data,rf).prediction_model()
# Out:
# 'The News is Fake'
